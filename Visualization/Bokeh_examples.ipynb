# %% [markdown]
# ## Starting with Bokeh
# #### (Examples extracted from the main website)

# %%
import numpy as np

from bokeh.plotting import figure, output_notebook, show
from bokeh.io import output_notebook
output_notebook()

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# output to static HTML file (with CDN resources)
#output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")


TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vecorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8229c70-675a-4234-92f1-4600edc38c7c">Loading BokehJS ...</span>
#     </div>

# %%
# show the results
show(p)
# Out:
#     <div class="plotdiv" id="98007a89-d42f-4f3e-a1dd-226d23b7b868"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98007a89-d42f-4f3e-a1dd-226d23b7b868");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98007a89-d42f-4f3e-a1dd-226d23b7b868' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7679397a-8732-4bdc-874d-fa31f7544fb6":{"roots":{"references":[{"attributes":{"plot":{"id":"463e25ea-3e9c-4edf-9987-65f02bca2d0e","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a7596d2-d526-45c7-b050-e9f4e91e2c87","type":"BasicTicker"}},"id":"ced9f39b-5e75-4af5-84c5-fb926fbfaa8b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"93e5ccdc-39c2-48fb-8dee-263f54375a47","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"}},"id":"a472a659-447e-43fa-b70d-f2c95035909e","type":"CrosshairTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99f749a0-1396-4a99-a118-f31adf212b24","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"5e601217-c26a-452b-a7bd-7eba4cc486dd","type":"BoxAnnotation"},"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"}},"id":"d6e18520-9095-4d75-97fe-b81412343174","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":100},"id":"84b60f6d-fddf-4430-b997-136d988e254b","type":"Range1d"},{"attributes":{"formatter":{"id":"3a29ea1e-8450-44b5-ab51-c070c5008189","type":"BasicTickFormatter"},"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"},"ticker":{"id":"72bef614-fec8-4ca4-ac85-18f761ce7d23","type":"BasicTicker"}},"id":"e1528492-5eac-40f6-849a-b83fa0942809","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["radius","y","x","fill_color"],"data":{"fill_color":["#332696","#349596","#ab8296","#ea4296","#9c5796","#f52996","#5a2d96","#b79196","#435796","#872896","#cd7e96","#92ad96","#49a096","#8d4196","#ea6496","#4ee196","#37a996","#d04796","#895596","#89a096","#ec5b96","#664096","#846b96","#9a2696","#352996","#ec2e96","#527996","#34b296","#3b2296","#9b4196","#aec396","#d44296","#c3e396","#c8c096","#ed9396","#83bb96","#d4a696","#e9a096","#d39596","#81d696","#98da96","#c33596","#dd6c96","#589996","#81b596","#aed996","#356796","#32b996","#844996","#e79f96","#e72896","#b9b196","#4b5f96","#dbb296","#541f96","#bf4896","#e13596","#6d6d96","#807196","#5fdc96","#b5dd96","#f85296","#e6b496","#b6c296","#5b8e96","#989096","#77df96","#3f2c96","#bb8596","#4b4096","#916f96","#a72996","#6e5696","#673696","#78c596","#95b496","#852096","#ba5d96","#bda096","#4ca396","#bdda96","#daa296","#3ea096","#55d596","#345a96","#97ad96","#5b8b96","#568d96","#f43996","#64db96","#d6b296","#53d296","#c5bb96","#dabc96","#cc5b96","#7f9796","#5fc396","#e4c096","#357f96","#5c8496","#70e196","#de7896","#885396","#f94596","#479896","#99e096","#5bdc96","#c83796","#bc5496","#bed296","#e59a96","#66da96","#80d496","#eead96","#9ad696","#c4c596","#ee2d96","#4f8e96","#673a96","#813c96","#398696","#7a4a96","#8a3496","#684696","#9acc96","#887996","#c5d396","#cc2b96","#b97a96","#46b596","#652d96","#e0ca96","#d38096","#71a796","#40ca96","#b41e96","#3c9c96","#4c5596","#9f3696","#d67996","#7dbe96","#e47096","#73cc96","#d59796","#9b6996","#d7ba96","#477296","#b7aa96","#81dd96","#e31e96","#4a7196","#e9ac96","#33d196","#6be196","#bbb996","#c02596","#c8d196","#e74d96","#3e9b96","#e3d996","#9c5696","#6f8996","#f9d796","#6d4596","#7b3a96","#aa2a96","#5f5996","#de2c96","#859e96","#4fbf96","#a56596","#8dbd96","#d1cb96","#ee9096","#b75696","#85a996","#a43796","#374696","#edad96","#91c596","#984f96","#908896","#392c96","#332c96","#872996","#c6c596","#a02396","#a88296","#939596","#b13696","#90cc96","#439b96","#638c96","#dd6b96","#aca79 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %%
from bokeh.models import HoverTool
from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.sampledata.us_counties import data as counties

from bokeh.sampledata.unemployment import data as unemployment

# %%
counties = {
    code: county for code, county in counties.items() if county["state"] == "ny"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

# %%
colors = ["#F1EEF6", "#D4B9DA", "#C994C7", "#DF65B0", "#DD1C77", "#980043"]

# %%
county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment[county_id] for county_id in counties]
county_colors = [colors[int(rate/3)] for rate in county_rates]

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    color=county_colors,
    name=county_names,
    rate=county_rates,
))

TOOLS="pan,wheel_zoom,box_zoom,reset,hover,save"

p = figure(title="NY Unemployment 2009", tools=TOOLS)

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3e241bda-738c-4501-8512-278692415aa1">Loading BokehJS ...</span>
#     </div>

# %%
p.patches('x', 'y', source=source,
          fill_color='color', fill_alpha=0.7,
          line_color="white", line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Name", "@name"),
    ("Unemployment rate)", "@rate%"),
    ("(Long, Lat)", "($x, $y)"),
]

# %%
output_file("ny.html", title="ny.py example")
show(p)
# Out:
#     <div class="plotdiv" id="16c50c66-8528-4acb-aa35-a2db4b5e3ce2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("16c50c66-8528-4acb-aa35-a2db4b5e3ce2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '16c50c66-8528-4acb-aa35-a2db4b5e3ce2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e30d90f8-0c61-4c5e-9d28-3d5d5eedfb42":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"xs":{"field":"x"},"ys":{"field":"y"}},"id":"34243d7b-55e9-437f-b259-955f5a30960f","type":"Patches"},{"attributes":{"plot":{"id":"463e25ea-3e9c-4edf-9987-65f02bca2d0e","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a7596d2-d526-45c7-b050-e9f4e91e2c87","type":"BasicTicker"}},"id":"ced9f39b-5e75-4af5-84c5-fb926fbfaa8b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"93e5ccdc-39c2-48fb-8dee-263f54375a47","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"76cbee85-9fe4-4b4c-8710-0b10c279dfdf","type":"DataRange1d"},{"attributes":{"plot":{"id":"463e25ea-3e9c-4edf-9987-65f02bca2d0e","subtype":"Figure","type":"Plot"}},"id":"e9894a44-8e9e-436d-9aea-7abf6b0276b3","type":"ResizeTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99f749a0-1396-4a99-a118-f31adf212b24","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"5e601217-c26a-452b-a7bd-7eba4cc486dd","type":"BoxAnnotation"},"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"}},"id":"d6e18520-9095-4d75-97fe-b81412343174","type":"BoxZoomTool"},{"attributes":{"overlay":{"id":"09bfc676-8545-4707-967d-f44c70a924a3","type":"PolyAnnotation"},"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"}},"id":"774570dd-c7bf-4536-bfa9-d8b14081da8b","type":"LassoSelectTool"},{"attributes":{},"id":"7aa98e00-4a11-4827-9965-0e32a714bb17","type":"BasicTicker"},{"attributes":{"formatter":{"id":"3a29ea1e-8450-44b5-ab51-c070c5008189","type":"BasicTickFormatter"},"plot":{"id":"9bc47757-5ac0-452a-924a-e08e5761f717","subtype":"Figure","type":"Plot"},"ticker":{"id":"72bef614-fec8-4ca4-ac85-18f761ce7d23","type":"BasicTicker"}},"id":"e1528492-5eac-40f6-849a-b83fa0942809","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3a10f0b8-d74a-4cd3-b053-b32556d08031","type":"ColumnDataSource"},"glyph":{"id":"4b0410c3-8ef8-479c-8d01-36df6d9bac11","type":"Patches"},"hover_glyph":null,"nonselection_glyph":{"id":"34243d7b-55e9-437f-b259-955f5a30960f","type":"Patches"},"selection_glyph":null},"id":"b4f7024c-79e8-4fc0-9350-91031d6f907f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["radius","y","x","fill_color"],"data":{"fill_color":["#332696","#349596","#ab8296","#ea4296","#9c5796","#f52996","#5a2d96","#b79196","#435796","#872896","#cd7e96","#92ad96","#49a096","#8d4196","#ea6496","#4ee196","#37a996","#d04796","#895596","#89a096","#ec5b96","#664096","#846b96","#9a2696","#352996","#ec2e96","#527996","#34b296","#3b2296","#9b4196","#aec396","#d44296","#c3e396","#c8c096","#ed9396","#83bb96","#d4a696","#e9a096","#d39596","#81d696","#98da96","#c33596","#dd6c96","#589996","#81b596","#aed996","#356796","#32b996","#844996","#e79f96","#e72896","#b9b196","#4b5f96","#dbb296","#541f96","#bf4896","#e13596","#6d6d96","#807196","#5fdc96","#b5dd96","#f85296","#e6b496","#b6c296","#5b8e96","#989096","#77df96","#3f2c96","#bb8596","#4b4096","#916f96","#a72996","#6e5696","#673696","#78c596","#95b496","#852096","#ba5d96","#bda096","#4ca396","#bdda96","#daa296","#3ea096","#55d596","#345a96","#97ad96","#5b8b96","#568d96","#f43996","#64db96","#d6b296","#53d296","#c5bb96","#dabc96","#cc5b96","#7f9796","#5fc396","#e4c096","#357f96"," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>
