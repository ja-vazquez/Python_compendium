# %% [markdown]
# # Seaborn, Bokeh
#
#
# # Mayavi, Scikit-learn

# %% [markdown]
# # https://www.data-to-viz.com/

# %%
# pip install BeautifulSoup4

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
sns.set()
#sns.set(style="darkgrid")

# %%
sns.get_dataset_names()
# Out:
# [u'anscombe',
#  u'attention',
#  u'brain_networks',
#  u'car_crashes',
#  u'diamonds',
#  u'dots',
#  u'exercise',
#  u'flights',
#  u'fmri',
#  u'gammas',
#  u'iris',
#  u'mpg',
#  u'planets',
#  u'tips',
#  u'titanic']

# %%
df = sns.load_dataset('iris')

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ## Histograms

# %%
sns.distplot( df["sepal_length"] , color="skyblue", label="Sepal Length")
sns.distplot( df["sepal_width"] , color="red", label="Sepal Width", rug=False)
#sns.plt.legend()

# %%
# Then you can pass arguments to each type:
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='scatter', s=100, color='m', 
              edgecolor="skyblue", linewidth=2)

# %%
# Custom the color
sns.set(style="white", color_codes=True)
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='kde', color="skyblue")

# %% [markdown]
# ### https://www.d3-graph-gallery.com/graph/density_slider.html

# %% [markdown]
# # Boxplot

# %%
# Usual boxplot
ax = sns.boxplot(x='species', y='sepal_length', data=df) #, notch=True)

# Add jitter with the swarmplot function.
ax = sns.swarmplot(x='species', y='sepal_length', data=df, color="grey")

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/boxplot_horizontal.html

# %% [markdown]
# ## Scatter

# %%
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], 
            line_kws={"color":"r","alpha":0.7,"lw":5})

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=True, 
           hue='species', legend=False, markers=["o", "x", "1"], palette="Set2")
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
sns.pairplot(df, kind="reg", diag_kind="kde")

# %%
sns.pairplot(df, kind="scatter", hue="species", markers=["o", "s", "D"], palette="Set2")

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/scatter_animation_start.html

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/violin_jitter.html

# %% [markdown]
# ## Connected scatter plots

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/connectedscatter_legend.html

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/line_filter.html

# %% [markdown]
# ## Contour plots

# %%
sns.kdeplot(df.sepal_width, df.sepal_length)

# %%
sns.kdeplot(df.sepal_width, df.sepal_length, cmap="Blues", shade=True, shade_lowest=True, )

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/density2d_shading.html

# %% [markdown]
# ## Area chart

# %%
# Create a dataset
my_count=["France","Australia","Japan","USA","Germany","Congo","China","England","Spain","Greece","Marocco","South Africa","Indonesia","Peru","Chili","Brazil"]
df = pd.DataFrame({
"country":np.repeat(my_count, 10),
"years":range(2000, 2010) * 16,
"value":np.random.rand(160)
})
 
# Create a grid : initialize it
g = sns.FacetGrid(df, col='country', hue='country', col_wrap=4, )
 
# Add the line over the area with the plot function
g = g.map(plt.plot, 'years', 'value')
 
# Fill the area with fill_between
g = g.map(plt.fill_between, 'years', 'value', alpha=0.2).set_titles("{col_name} country")
 
# Control the title of each facet
g = g.set_titles("{col_name}")
 
# Add a title for the whole plo
plt.subplots_adjust(top=0.92)
g = g.fig.suptitle('Evolution of the value of stuff in 16 countries')

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/area_brushZoom.html

# %% [markdown]
# ## Bubble plot

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/bubble_template.html

# %% [markdown]
# ## Stacked area

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/stackedarea_template.html

# %% [markdown]
# ## Streamgraph

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/streamgraph_template.html

# %% [markdown]
# ## Ridgeline

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/ridgeline_animation.html

# %% [markdown]
# ## heatmap

# %%
df = np.random.randn(30, 30)

sns.heatmap(df, cmap="PiYG")

# %% [markdown]
# ## Dendogram

# %%
# Libraries
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
 
# Data set
url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
df = pd.read_csv(url)
df = df.set_index('model')
df
 
# Prepare a vector of color mapped to the 'cyl' column
my_palette = dict(zip(df.cyl.unique(), ["orange","yellow","brown"]))
row_colors = df.cyl.map(my_palette)
 
# plot
sns.clustermap(df, metric="correlation", method="single", cmap="Blues", standard_scale=1, row_colors=row_colors)

# %% [markdown]
# ## https://bl.ocks.org/mbostock/e9ba78a2c1070980d1b530800ce7fa2b

# %% [markdown]
# ## Radar chart

# %% [markdown]
# ## http://bl.ocks.org/nbremer/21746a9668ffdf6d8242

# %% [markdown]
# ## Time Series

# %%
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)

# %% [markdown]
# ## Facet grid

# %%
# Generate an example radial datast
r = np.linspace(0, 10, num=100)
df = pd.DataFrame({'r': r, 'slow': r, 'medium': 2 * r, 'fast': 4 * r})

# Convert the dataframe to long-form or "tidy" format
df = pd.melt(df, id_vars=['r'], var_name='speed', value_name='theta')

# Set up a grid of axes with a polar projection
g = sns.FacetGrid(df, col="speed", hue="speed",
                  subplot_kws=dict(projection='polar'), height=4.5,
                  sharex=False, sharey=False, despine=False)

# Draw a scatterplot onto each axes in the grid
g.map(sns.scatterplot, "theta", "r")

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
 
# Create a list of word
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
 
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0, background_color="skyblue").generate(text)
 
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
#https://github.com/amueller/word_cloud/blob/master/examples/masked.py

#from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS


text = open('data/alice.txt').read()
alice_mask = np.array(Image.open("data/alice_mask.png"))

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask, colormap='hsv',
               stopwords=stopwords, contour_width=1, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
#wc.to_file("alice.png")

# show
plt.figure(figsize=(20,25))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 899.5, 899.5, -0.5)

# %% [markdown]
# ## http://bl.ocks.org/joews/9697914

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS

text = open('Morelos.txt').read()
alice_mask = np.array(Image.open('Morelos.png'))

stopwords = set(STOPWORDS)
stopwords.add('said')

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask, colormap='hsv', repeat=True,
               stopwords=stopwords, contour_width=1, contour_color='steelblue')


wc.generate(text)
wc.to_file('alice.png')

plt.figure(figsize=(20,25))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 992.5, 968.5, -0.5)

# %%
# %matplotlib inline
import scipy
import scipy.special 
import numpy 
import matplotlib
import matplotlib.pyplot 
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm, colors

# %%
l = 2     # Grado del armónico esférico.
m = 1     # Orden del armónico esférico.
phi, theta = numpy.mgrid[0:2*numpy.pi:200j, 0:numpy.pi:100j] # Arreglo de variables angulares
R = numpy.abs(scipy.special.sph_harm(m, l, phi, theta))      # Arreglo de valores absolutos de Y^m_ l
# Conversión de polares a coordenadas cartesianas:
X = R * numpy.sin(theta) * numpy.cos(phi)
Y = R * numpy.sin(theta) * numpy.sin(phi)
Z = R * numpy.cos(theta)
# Normalizar R para que los colores del plot cubran todo el rango del colormap:
N = R/R.max()    
fig, ax = matplotlib.pyplot.subplots(subplot_kw=dict(projection='3d'), figsize=(14,10))
im = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=cm.jet(N))
ax.set_title('$|Y^m_ l|$', fontsize=20)
m = cm.ScalarMappable(cmap=cm.jet)
m.set_array(R)    
fig.colorbar(m, shrink=0.8);

# %%
l = 2    # Grado del armónico esférico
m = 1    # Orden del armónico esférico
phi, theta = numpy.mgrid[0:2*numpy.pi:200j, 0:numpy.pi:100j] # Arreglo de variables angulares
R = scipy.special.sph_harm(m, l, phi, theta).real            # Arreglo de valores de Y^m_ l
# Conversión de polares a coordenadas cartesianas:
X = R * numpy.sin(theta) * numpy.cos(phi)
Y = R * numpy.sin(theta) * numpy.sin(phi)
Z = R * numpy.cos(theta)
# Normalizar R para que los colores del plot cubran todo el rango del colormap:
norm = colors.Normalize()
fig, ax = matplotlib.pyplot.subplots(subplot_kw=dict(projection='3d'), figsize=(14,10))
m = cm.ScalarMappable(cmap=cm.jet)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=cm.jet(norm(R)))
ax.set_title('$|Y^m_ l|$', fontsize=20)
m.set_array(R)
fig.colorbar(m, shrink=0.8);

# %% [markdown]
# ## Parallel plots

# %%
from pandas.tools.plotting import parallel_coordinates
 
# Take the iris dataset
import seaborn as sns
data = sns.load_dataset('iris')
 
# Make the plot
parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:8: FutureWarning: 'pandas.tools.plotting.parallel_coordinates' is deprecated, import 'pandas.plotting.parallel_coordinates' instead.

# %% [markdown]
# ## http://bl.ocks.org/syntagmatic/3150059

# %% [markdown]
# ## Lollipop

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/lollipop_button_data_csv.html

# %% [markdown]
# ## Circular barplot

# %% [markdown]
# ## https://observablehq.com/@d3/radial-stacked-bar-chart

# %% [markdown]
# ## Venn diagrams

# %%
from matplotlib_venn import venn2
 
# First way to call the 2 group Venn diagram:
venn2(subsets = (10, 5, 2), set_labels = ('Group A', 'Group B'))
plt.show()
 
# Second way
#venn2([set(['A', 'B', 'C', 'D']), set(['D', 'E', 'F'])])

# %% [markdown]
# ## donut plots

# %%
# create data
names='groupA', 'groupB', 'groupC', 'groupD',
size=[12,11,3,30]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

# Give color names
plt.pie(size, labels=names, colors=['red','green','blue','skyblue'])
p=plt.gcf()
p.gca().add_artist(my_circle)

# %% [markdown]
# ## http://bl.ocks.org/dbuezas/9306799

# %% [markdown]
# ## Circular packing

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/circularpacking_template.html

# %% [markdown]
# ## Maps

# %% [markdown]
# ## https://observablehq.com/@d3/choropleth

# %% [markdown]
# ## https://bl.ocks.org/sjengle/2e58e83685f6d854aa40c7bc546aeb24

# %% [markdown]
# ## http://prag.ma/code/d3-cartogram/#natincrate/2011

# %% [markdown]
# ## https://www.d3-graph-gallery.com/graph/bubblemap_template.html

# %% [markdown]
# ## Chord diagram

# %% [markdown]
# ## http://bl.ocks.org/nbremer/94db779237655907b907

# %% [markdown]
# ## Networks

# %% [markdown]
# ## https://observablehq.com/@d3/force-directed-graph

# %% [markdown]
# ## Sankey diagram

# %% [markdown]
# ## https://observablehq.com/@d3/sankey-diagram

# %% [markdown]
# ## Arc diagram

# %% [markdown]
# ## http://bl.ocks.org/mayblue9/dcc49ef6e3888f37f755177c4a248f2c

# %% [markdown]
# # Art from data

# %% [markdown]
# # https://www.r-graph-gallery.com/portfolio/data-art/
