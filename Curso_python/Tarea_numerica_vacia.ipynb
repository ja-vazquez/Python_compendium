# %%
import matplotlib.pyplot as plt
from scipy import optimize,  interpolate, integrate
import seaborn as sns
import numpy as np
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Usar SEABORN para graficar

# %%
sns.set()

# %% [markdown]
# ## Leer archivos con PANDAS y almacenar

# %%
pdf.head()
# Out:
#           x          y
# 0  0.000000 -14.715795
# 1  0.040404 -13.027356
# 2  0.080808 -13.272850
# 3  0.121212 -14.358241
# 4  0.161616 -15.505933

# %%
pdg.head()
# Out:
#           x          y
# 0  0.000000  50.039303
# 1  0.040404  46.502652
# 2  0.080808  45.187666
# 3  0.121212  42.193232
# 4  0.161616  43.630388

# %% [markdown]
# ## Graficar archivos

# %% [markdown]
# ## Sumar componentes y's y graficar

# %% [markdown]
# ## Ajustar una funcion cuadratica y encontrar coeficientes

# %%
## Ajustar una funcion quadratica a la suma

def f(t, a, b, c):
    return a*t**2 + b*t + c

# %% [markdown]
# ## GRaficar promedios y matriz de covarianza

# %% [markdown]
# ## Graficar mejor ajuste de la cuadratica

# %% [markdown]
# ## El mejor ajuste convertir a una funcion

# %% [markdown]
# ## Encontrar raices

# %%
# Out:
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 3.0604860809470593

# %% [markdown]
# ## Encontrar minimo

# %%
# Out:
#       fun: -10.396763882201286
#  hess_inv: array([[0.0631684]])
#       jac: array([-0.24113715])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 173
#       nit: 1
#      njev: 56
#    status: 2
#   success: False
#         x: array([2.05219916])

# %% [markdown]
# ## Calcular derivadas

# %% [markdown]
# ## Graficar tangentes a raices y funcion

# %% [markdown]
# ## Graficar area entre parabola y tangentes

# %%
# Out:
# (1, 3)

# %% [markdown]
# ## Encotrar area total

# %%
area_total
# Out:
# 6.989304792746549
